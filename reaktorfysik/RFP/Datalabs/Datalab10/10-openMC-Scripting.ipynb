# %% [markdown]
# # OpenMC: Scripting
#
# Please indicate your name below, since you will need to submit this notebook completed latest the day after the datalab.
#
# Don't forget to save your progress during the datalab to avoid any loss due to crashes.

# %%
name='Mikkel'

# %% [markdown]
# **Note** you will need to run Jupyter from an environment where openMC is available in order to run this notebook!
#
# During the first openMC datalab, we have covered the basics, and covered how to write a basic input, how to run it and how to post-process the results. Today we go one step further and will explore the real power of the python API. Namely that we can automatize calculations simply by defining a function which creates the input for us. Then we can write loops and automatically update our model. For this we will use the `Model()` class of openMC. This basically means that instead of exporting all the details of the run into xml, openMC will take care of this, when we call the `.run()` method of the class.
#
# We will learn about
#
# - the built in criticality search functionality of openMC (which is a wrapper for the scipy.optimization methods).
# - write our own script to determine the void-coefficient change of the LWR pincell at various fuel to moderator ratio
# - will write a tally to investigate the fuel utilization factor and the resonance escape probability.
#
# Let's get started with doing the necessary imports!

# %%
import openmc
import openmc.model
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Experiment 1
#
# First we will calculate the boron concentration at which the k-infinity of the pincell is 1.2. For a finite core, of course usually we would like to know the critical boron content, but now we have reflective boundaries (ie. no leakage), so for the demonstration we aim for higher than 1.0 multiplication factor.
#
# First, we will define the `pincell()` function. The expressions inside this function are probably similar from the previous datalab. We only did some small changes:
# - we have decreased the number of particles per batch: although we will have a worse accuracy, but we will need to run this input several times, and it is not sustainable to spend the datalab with waiting for the calculations to finish
# - we have not included a numeric ID for the `Material()` instances. In this case openMC will increment the ID number. Since in these examples we do not use the IDs for anything, we can live without controlling it. (If we kept the ID, openMC would send a warning all the time that the ID was already in use. It is a warning, so not an error, but still annoying).
# - we have added a small amount of boron to the water (in reality boric acid is added to the water)
# - we have removed the calls to the `export_to_xml()` methods.
# - since we removed the tallies, we included `settings.output = {'tallies': False}` (this is to make sure that in case a 'tallies.xml' file is present from an other run it is not used)
# - finally, at the end we create an instance `model = openmc.model.Model(geom, mats, settings)` and return it.

# %%
def pincell(bppm):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    water.set_density('g/cm3', 0.74)
    #THIS IS THE IMPORTANT NEW LINE COMPARED TO BEFORE!
    water.add_element('B', bppm*1e-6) 
    ###################################################
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    pitch = 1.26
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %% [markdown]
# Now we can perform a search for the boron concentration at which the multiplication factor is 1.2. This is a fairly similar root finding problem that we have done in datalab 5. In fact, if you look into the [source code](https://docs.openmc.org/en/stable/_modules/openmc/search.html#search_for_keff) of `openmc.search_for_keff` you will see that the function wraps the methods of scipy.optimize.
#
# We will need to pass as an input the function `pincell`, we can specify the lower and upper bound of the boron content to limit the interval of the search, and set the tolerance (ie. how accurate we want to be with the desired multiplication factor). The search will need some time, so while you wait you can start reading the next experiment!

# %%
os.system('rm *h5')
crit_ppm, guesses, keffs = openmc.search_for_keff(pincell, target=1.2, bracket=[2000., 3500.],
                                                  tol=1e-2, print_iterations=True)

print('Critical Boron Concentration: {:4.0f} ppm'.format(crit_ppm))
# Out:
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:08:32
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.25159
#         2/1    1.23653
#         3/1    1.38337
#         4/1    1.30150
#         5/1    1.29993
#         6/1    1.28094
#         7/1    1.30124
#         8/1    1.23297
#         9/1    1.19107
#        10/1    1.16878
#        11/1    1.26739
#        12/1    1.26658    1.26698 +/- 0.00040
#        13/1    1.30979    1.28125 +/- 0.01427
#        14/1    1.13534    1.24477 +/- 0.03785
#        15/1    1.24145    1.24411 +/- 0.02932
#        16/1    1.30589    1.25441 +/- 0.02606
#        17/1    1.15906    1.24078 +/- 0.02590
#        18/1    1.41459    1.26251 +/- 0.03123
#        19/1    1.16676    1.25187 +/- 0.02952
#        20/1    1.17299    1.24398 +/- 0.02756
#        21/1    1.21507    1.24136 +/- 0.02507
#        22/1    1.15591    1.23423 +/- 0.02396
#        23/1    1.20058    1.23165 +/- 0.02220
#        24/1    1.37992    1.24224 +/- 0.02312
#        25/1    1.22158    1.24086 +/- 0.02157
#        87/1    1.44784    1.27248 +/- 0.00865
#        88/1    1.33842    1.27332 +/- 0.00858
#        89/1    1.28650    1.27349 +/- 0.00847
#        90/1    1.26885    1.27343 +/- 0.00836
#        91/1    1.34545    1.27432 +/- 0.00831
#        92/1    1.22589    1.27373 +/- 0.00823
#        93/1    1.26972    1.27368 +/- 0.00813
#        94/1    1.21572    1.27299 +/- 0.00806
#        95/1    1.31032    1.27343 +/- 0.00798
#        96/1    1.18180    1.27236 +/- 0.00795
#        97/1    1.22396    1.27181 +/- 0.00788
#        98/1    1.29914    1.27212 +/- 0.00780
#        99/1    1.39576    1.27351 +/- 0.00783
#       100/1    1.27612    1.27354 +/- 0.00775
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.5008e+00 seconds
#    Reading cross sections          = 5.3766e+00 seconds
#  Total time in simulation          = 9.6893e+00 seconds
#    Time in transport only          = 9.4513e+00 seconds
#    Time in inactive batches        = 9.5255e-01 seconds
#    Time in active batches          = 8.7368e+00 seconds
#    Time synchronizing fission bank = 7.2961e-02 seconds
#      Sampling source sites         = 2.6140e-02 seconds
#      SEND/RECV source sites        = 2.5395e-02 seconds
#    Time accumulating tallies       = 3.5971e-04 seconds
#    Time writing statepoints        = 5.2175e-02 seconds
#  Total time for finalization       = 7.9541e-05 seconds
#  Total time elapsed                = 1.5276e+01 seconds
#  Calculation Rate (inactive)       = 5249.06 particles/second
#  Calculation Rate (active)         = 5150.64 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.26236 +/- 0.00608
#  k-effective (Track-length)  = 1.27354 +/- 0.00775
#  k-effective (Absorption)    = 1.24829 +/- 0.00472
#  Combined k-effective        = 1.25377 +/- 0.00454
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 1; Guess of 2.00e+03 produced a keff of 1.25377 +/- 0.00454
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:08:47
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.10001
#         2/1    1.14934
#         3/1    1.23577
#         4/1    1.18681
#         5/1    1.16585
#         6/1    1.27000
#         7/1    1.10760
#         8/1    1.13573
#         9/1    1.21973
#        10/1    1.26233
#        11/1    1.21627
#        12/1    1.22170    1.21898 +/- 0.00272
#        13/1    1.12445    1.18747 +/- 0.03155
#        14/1    1.21692    1.19483 +/- 0.02349
#        15/1    1.22174    1.20021 +/- 0.01898
#        16/1    1.19179    1.19881 +/- 0.01556
#        17/1    1.14890    1.19168 +/- 0.01496
#        18/1    1.14738    1.18614 +/- 0.01409
#        19/1    1.09218    1.17570 +/- 0.01623
#        20/1    1.19069    1.17720 +/- 0.01459
#        21/1    1.19113    1.17847 +/- 0.01326
#        22/1    1.10987    1.17275 +/- 0.01339
#        23/1    1.21134    1.17572 +/- 0.01267
#        24/1    1.09402    1.16988 +/- 0.01310
#        25/1    1.16542    1.16959 +/- 0.01220
#        26/1    1.15921    1.16894 +/- 0.01143
#        27/1    1.32896    1.17835 +/- 0.01428
#        28/1    1.11368    1.17476 +/- 0.01393
#        29/1    1.20553    1.17638 +/- 0.01328
#        30/1    1.08288    1.17170 +/- 0.01344
#        31/1    1.16678    1.17147 +/- 0.01278
#        93/1    1.19702    1.17464 +/- 0.00631
#        94/1    1.14201    1.17425 +/- 0.00625
#        95/1    1.20651    1.17463 +/- 0.00619
#        96/1    1.28702    1.17594 +/- 0.00625
#        97/1    1.15317    1.17568 +/- 0.00619
#        98/1    1.20975    1.17607 +/- 0.00613
#        99/1    1.10082    1.17522 +/- 0.00612
#       100/1    1.05997    1.17394 +/- 0.00618
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.1112e+00 seconds
#    Reading cross sections          = 4.9964e+00 seconds
#  Total time in simulation          = 9.1334e+00 seconds
#    Time in transport only          = 8.9195e+00 seconds
#    Time in inactive batches        = 9.2402e-01 seconds
#    Time in active batches          = 8.2094e+00 seconds
#    Time synchronizing fission bank = 5.9962e-02 seconds
#      Sampling source sites         = 2.9384e-02 seconds
#      SEND/RECV source sites        = 2.4722e-02 seconds
#    Time accumulating tallies       = 4.7492e-04 seconds
#    Time writing statepoints        = 4.3553e-02 seconds
#  Total time for finalization       = 7.9292e-05 seconds
#  Total time elapsed                = 1.4332e+01 seconds
#  Calculation Rate (inactive)       = 5411.13 particles/second
#  Calculation Rate (active)         = 5481.54 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.16934 +/- 0.00508
#  k-effective (Track-length)  = 1.17394 +/- 0.00618
#  k-effective (Absorption)    = 1.17084 +/- 0.00466
#  Combined k-effective        = 1.17101 +/- 0.00402
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 2; Guess of 3.50e+03 produced a keff of 1.17101 +/- 0.00402
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:09:02
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13935
#         2/1    1.20825
#         3/1    1.17646
#         4/1    1.21702
#         5/1    1.22986
#         6/1    1.25387
#         7/1    1.11364
#         8/1    1.15853
#         9/1    1.24782
#        10/1    1.24269
#        11/1    1.27952
#        12/1    1.22669    1.25310 +/- 0.02642
#        13/1    1.22918    1.24513 +/- 0.01721
#        14/1    1.32923    1.26616 +/- 0.02429
#        15/1    1.23299    1.25952 +/- 0.01995
#        16/1    1.18090    1.24642 +/- 0.02091
#        17/1    1.23593    1.24492 +/- 0.01773
#        18/1    1.15484    1.23366 +/- 0.01904
#        19/1    1.25140    1.23563 +/- 0.01691
#        20/1    1.28350    1.24042 +/- 0.01586
#        21/1    1.34287    1.24973 +/- 0.01711
#        22/1    1.09002    1.23642 +/- 0.02052
#        23/1    1.24556    1.23713 +/- 0.01889
#        24/1    1.31023    1.24235 +/- 0.01825
#        25/1    1.18789    1.23872 +/- 0.01737
#        26/1    1.22800    1.23805 +/- 0.01626
#        27/1    1.15287    1.23304 +/- 0.01608
#        28/1    1.12924    1.22727 +/- 0.01622
#        29/1    1.23653    1.22776 +/- 0.01535
#        30/1    1.26157    1.22945 +/- 0.01466
#        31/1    1.00022    1.21853 +/- 0.01771
#        32/1    1.11133    1.21366 +/- 0.01757
#        33/1    1.20347    1.21322 +/- 0.01680
#        34/1    1.45440    1.22327 +/- 0.01896
#        35/1    1.27976    1.22553 +/- 0.01833
#        36/1    1.27295    1.22735 +/- 0.01770
#        37/1    1.24465    1.22799 +/- 0.01705
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0692e+00 seconds
#    Reading cross sections          = 4.9569e+00 seconds
#  Total time in simulation          = 8.3739e+00 seconds
#    Time in transport only          = 8.2023e+00 seconds
#    Time in inactive batches        = 8.5946e-01 seconds
#    Time in active batches          = 7.5145e+00 seconds
#    Time synchronizing fission bank = 5.2323e-02 seconds
#      Sampling source sites         = 2.4360e-02 seconds
#      SEND/RECV source sites        = 2.4241e-02 seconds
#    Time accumulating tallies       = 3.4612e-04 seconds
#    Time writing statepoints        = 3.8604e-02 seconds
#  Total time for finalization       = 8.4875e-05 seconds
#  Total time elapsed                = 1.3528e+01 seconds
#  Calculation Rate (inactive)       = 5817.59 particles/second
#  Calculation Rate (active)         = 5988.45 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.23350 +/- 0.00613
#  k-effective (Track-length)  = 1.22546 +/- 0.00795
#  k-effective (Absorption)    = 1.22166 +/- 0.00468
#  Combined k-effective        = 1.22405 +/- 0.00460
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 3; Guess of 2.75e+03 produced a keff of 1.22405 +/- 0.00460
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:09:16
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.11549
#         2/1    1.22025
#         3/1    1.33813
#         4/1    1.14821
#         5/1    1.30862
#         6/1    1.24557
#         7/1    1.14035
#         8/1    1.20829
#         9/1    1.21521
#        10/1    1.13544
#        11/1    1.28370
#        12/1    1.18903    1.23637 +/- 0.04733
#        13/1    1.26450    1.24575 +/- 0.02889
#        14/1    1.24228    1.24488 +/- 0.02045
#        15/1    1.17343    1.23059 +/- 0.02133
#        16/1    1.21105    1.22733 +/- 0.01772
#        17/1    1.13879    1.21468 +/- 0.01960
#        18/1    1.28548    1.22353 +/- 0.01914
#        19/1    1.17162    1.21777 +/- 0.01784
#        20/1    1.27040    1.22303 +/- 0.01680
#        21/1    1.16677    1.21792 +/- 0.01604
#        22/1    1.24976    1.22057 +/- 0.01488
#        23/1    1.15732    1.21570 +/- 0.01453
#        24/1    1.25363    1.21841 +/- 0.01372
#        25/1    1.24857    1.22042 +/- 0.01293
#        26/1    1.15726    1.21648 +/- 0.01272
#        27/1    1.15695    1.21297 +/- 0.01245
#        28/1    1.34546    1.22033 +/- 0.01386
#        29/1    1.22395    1.22052 +/- 0.01311
#        30/1    1.15078    1.21704 +/- 0.01292
#        31/1    1.16943    1.21477 +/- 0.01249
#        32/1    1.19634    1.21393 +/- 0.01194
#        33/1    1.23316    1.21477 +/- 0.01144
#        34/1    1.19518    1.21395 +/- 0.01098
#        35/1    1.16428    1.21197 +/- 0.01072
#        36/1    1.19946    1.21148 +/- 0.01031
#        37/1    1.13276    1.20857 +/- 0.01034
#        38/1    1.31995    1.21255 +/- 0.01073
#        39/1    1.21535    1.21264 +/- 0.01035
#        40/1    1.20495    1.21239 +/- 0.01001
#        41/1    1.22811    1.21289 +/- 0.00969
#        42/1    1.25334    1.21416 +/- 0.00947
#        43/1    1.26099    1.21558 +/- 0.00929
#        44/1    1.21696    1.21562 +/- 0.00901
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0154e+00 seconds
#    Reading cross sections          = 4.9020e+00 seconds
#  Total time in simulation          = 8.1607e+00 seconds
#    Time in transport only          = 7.9657e+00 seconds
#    Time in inactive batches        = 8.7636e-01 seconds
#    Time in active batches          = 7.2844e+00 seconds
#    Time synchronizing fission bank = 5.7481e-02 seconds
#      Sampling source sites         = 2.8136e-02 seconds
#      SEND/RECV source sites        = 2.5806e-02 seconds
#    Time accumulating tallies       = 3.4621e-04 seconds
#    Time writing statepoints        = 4.8905e-02 seconds
#  Total time for finalization       = 7.8625e-05 seconds
#  Total time elapsed                = 1.3265e+01 seconds
#  Calculation Rate (inactive)       = 5705.39 particles/second
#  Calculation Rate (active)         = 6177.61 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.20902 +/- 0.00548
#  k-effective (Track-length)  = 1.21357 +/- 0.00634
#  k-effective (Absorption)    = 1.19847 +/- 0.00501
#  Combined k-effective        = 1.20420 +/- 0.00440
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 4; Guess of 3.12e+03 produced a keff of 1.20420 +/- 0.00440
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:09:29
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.10220
#         2/1    1.19677
#         3/1    1.22919
#         4/1    1.15886
#         5/1    1.20350
#         6/1    1.19617
#         7/1    1.03781
#         8/1    1.03692
#         9/1    1.19529
#        10/1    1.14166
#        11/1    1.13871
#        12/1    1.20338    1.17104 +/- 0.03233
#        13/1    1.16037    1.16749 +/- 0.01900
#        14/1    1.08537    1.14696 +/- 0.02454
#        15/1    1.15722    1.14901 +/- 0.01912
#        16/1    1.21009    1.15919 +/- 0.01864
#        17/1    1.22699    1.16887 +/- 0.01849
#        18/1    1.26555    1.18096 +/- 0.02006
#        19/1    1.25018    1.18865 +/- 0.01929
#        20/1    1.18637    1.18842 +/- 0.01726
#        21/1    1.14996    1.18493 +/- 0.01600
#        22/1    1.19220    1.18553 +/- 0.01461
#        23/1    1.22635    1.18867 +/- 0.01381
#        24/1    1.16870    1.18724 +/- 0.01286
#        25/1    1.28726    1.19391 +/- 0.01370
#        26/1    1.09484    1.18772 +/- 0.01424
#        27/1    1.27114    1.19263 +/- 0.01424
#        28/1    1.23503    1.19498 +/- 0.01363
#        29/1    1.11562    1.19081 +/- 0.01356
#        30/1    1.20842    1.19169 +/- 0.01289
#        31/1    1.18057    1.19116 +/- 0.01227
#        32/1    1.11753    1.18781 +/- 0.01217
#        33/1    1.10219    1.18409 +/- 0.01221
#        34/1    1.12075    1.18145 +/- 0.01199
#        35/1    1.22597    1.18323 +/- 0.01163
#        36/1    1.19743    1.18378 +/- 0.01119
#        37/1    1.22905    1.18545 +/- 0.01090
#        38/1    1.18631    1.18548 +/- 0.01050
#        39/1    1.23397    1.18716 +/- 0.01027
#        40/1    1.29199    1.19065 +/- 0.01052
#        41/1    1.26246    1.19297 +/- 0.01043
#        42/1    1.19914    1.19316 +/- 0.01010
#        43/1    1.20491    1.19352 +/- 0.00980
#        44/1    1.12853    1.19160 +/- 0.00970
#        45/1    1.05604    1.18773 +/- 0.01018
#        46/1    1.08677    1.18493 +/- 0.01029
#        47/1    1.15387    1.18409 +/- 0.01004
#        48/1    1.18498    1.18411 +/- 0.00977
#        49/1    1.23356    1.18538 +/- 0.00960
#        50/1    1.19563    1.18563 +/- 0.00936
#        80/1    1.13267    1.18859 +/- 0.00848
#        81/1    1.06336    1.18682 +/- 0.00854
#        82/1    1.08021    1.18534 +/- 0.00855
#        83/1    1.20852    1.18566 +/- 0.00844
#        84/1    1.11097    1.18465 +/- 0.00839
#        85/1    1.13419    1.18398 +/- 0.00830
#        86/1    1.17414    1.18385 +/- 0.00819
#        87/1    1.13314    1.18319 +/- 0.00811
#        88/1    1.30778    1.18479 +/- 0.00817
#        89/1    1.10044    1.18372 +/- 0.00813
#        90/1    1.11043    1.18280 +/- 0.00808
#        91/1    1.07132    1.18143 +/- 0.00810
#        92/1    1.18591    1.18148 +/- 0.00800
#        93/1    1.30951    1.18302 +/- 0.00805
#        94/1    1.15280    1.18266 +/- 0.00796
#        95/1    1.19305    1.18279 +/- 0.00787
#        96/1    1.28493    1.18397 +/- 0.00787
#        97/1    1.22138    1.18440 +/- 0.00779
#        98/1    1.19249    1.18450 +/- 0.00770
#        99/1    1.12033    1.18378 +/- 0.00765
#       100/1    1.24727    1.18448 +/- 0.00760
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0625e+00 seconds
#    Reading cross sections          = 4.9521e+00 seconds
#  Total time in simulation          = 8.1156e+00 seconds
#    Time in transport only          = 7.9131e+00 seconds
#    Time in inactive batches        = 8.5704e-01 seconds
#    Time in active batches          = 7.2585e+00 seconds
#    Time synchronizing fission bank = 5.8972e-02 seconds
#      Sampling source sites         = 2.7651e-02 seconds
#      SEND/RECV source sites        = 2.6650e-02 seconds
#    Time accumulating tallies       = 3.7154e-04 seconds
#    Time writing statepoints        = 4.6573e-02 seconds
#  Total time for finalization       = 8.3833e-05 seconds
#  Total time elapsed                = 1.3264e+01 seconds
#  Calculation Rate (inactive)       = 5834.01 particles/second
#  Calculation Rate (active)         = 6199.59 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18667 +/- 0.00610
#  k-effective (Track-length)  = 1.18448 +/- 0.00760
#  k-effective (Absorption)    = 1.18057 +/- 0.00454
#  Combined k-effective        = 1.18183 +/- 0.00438
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 7; Guess of 3.17e+03 produced a keff of 1.18183 +/- 0.00438
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:10:10
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.11099
#         2/1    1.19137
#         3/1    1.20304
#         4/1    1.13807
#         5/1    1.24872
#         6/1    1.22452
#         7/1    1.17585
#         8/1    1.03841
#         9/1    1.21380
#        10/1    1.22779
#        11/1    1.13450
#        12/1    1.21981    1.17716 +/- 0.04266
#        13/1    1.18603    1.18011 +/- 0.02480
#        14/1    1.12859    1.16723 +/- 0.02176
#        15/1    1.20923    1.17563 +/- 0.01883
#        16/1    1.29863    1.19613 +/- 0.02563
#        17/1    1.21408    1.19870 +/- 0.02181
#        18/1    1.23746    1.20354 +/- 0.01950
#        19/1    1.22423    1.20584 +/- 0.01735
#        20/1    1.18507    1.20376 +/- 0.01566
#        21/1    1.20352    1.20374 +/- 0.01416
#        22/1    1.15070    1.19932 +/- 0.01366
#        23/1    1.18451    1.19818 +/- 0.01262
#        24/1    1.23186    1.20059 +/- 0.01193
#        86/1    1.20887    1.20166 +/- 0.00735
#        87/1    1.16522    1.20119 +/- 0.00726
#        88/1    1.23978    1.20168 +/- 0.00719
#        89/1    1.10353    1.20044 +/- 0.00720
#        90/1    1.16674    1.20002 +/- 0.00713
#        91/1    1.20769    1.20011 +/- 0.00704
#        92/1    1.16097    1.19964 +/- 0.00697
#        93/1    1.03388    1.19764 +/- 0.00717
#        94/1    1.21423    1.19784 +/- 0.00708
#        95/1    1.09902    1.19667 +/- 0.00710
#        96/1    1.16115    1.19626 +/- 0.00703
#        97/1    1.22523    1.19659 +/- 0.00695
#        98/1    1.11745    1.19570 +/- 0.00693
#        99/1    1.33111    1.19722 +/- 0.00702
#       100/1    1.23555    1.19764 +/- 0.00695
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0613e+00 seconds
#    Reading cross sections          = 4.9500e+00 seconds
#  Total time in simulation          = 8.2329e+00 seconds
#    Time in transport only          = 8.0462e+00 seconds
#    Time in inactive batches        = 8.0805e-01 seconds
#    Time in active batches          = 7.4248e+00 seconds
#    Time synchronizing fission bank = 5.8188e-02 seconds
#      Sampling source sites         = 2.6013e-02 seconds
#      SEND/RECV source sites        = 2.7383e-02 seconds
#    Time accumulating tallies       = 3.4079e-04 seconds
#    Time writing statepoints        = 4.4568e-02 seconds
#  Total time for finalization       = 9.3000e-05 seconds
#  Total time elapsed                = 1.3383e+01 seconds
#  Calculation Rate (inactive)       = 6187.76 particles/second
#  Calculation Rate (active)         = 6060.75 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.19954 +/- 0.00536
#  k-effective (Track-length)  = 1.19764 +/- 0.00695
#  k-effective (Absorption)    = 1.19881 +/- 0.00452
#  Combined k-effective        = 1.19901 +/- 0.00399
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 8; Guess of 3.15e+03 produced a keff of 1.19901 +/- 0.00399
# Critical Boron Concentration: 3148 ppm

# %% [markdown]
# We can visualize the guesses by the optimization algorithm, and see how the boron content converged to the correct amount.

# %%
plt.figure()
for g,k in zip(guesses,keffs):
    plt.scatter(g,k.nominal_value,color='k')
plt.xlabel('boron content (ppm)')
plt.ylabel('k-inf')
plt.scatter(crit_ppm,1.2,color='r')
plt.show()

# %% [markdown]
# ## Experiment 2
#
# During the lectures we have learnt about the reactivity feedback coefficients. Today we are going to investigate the void coefficient for various moderator to fuel ratios. The moderator to fuel ratio can be defined in the rectangular pincell as
#
# $$mfr=\frac{p^2-r_{clad}^2\pi}{r_{fuel}^2\pi}$$
#
# can be simply modified by changing the pitch $p$.
#
# The void constant of the fuel can be modified by changing the density of the coolant. We can use the following simple relationship:
#
# $$\rho_{coolant}=\rho_0(1-void[\%]/100)$$
#
# where $\rho_0=0.74$ g/cm3. In practice, of course we will never obtain a zero density even for a fully voided core. Also, it is worth mentioning that void levels investigated here are never reached in normal operations for a PWR, but are however the nominal levels for a BWR. Nevertheless, the goal of the exercise is not to investigate exact reactor operation scenarios, rather to provide a physicist insight for understanding how significantly lowering the density of the moderator affects the multiplication factor.
#
# First create a `pincell()` function where the user can modify the pitch and the void content. The function should return a `Model()` object. (You do not need to include boron in the coolant for this exercise).

# %%
def pincell(pitch,void):
    
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    water.set_density('g/cm3', 0.74 * (1 - void / 100))
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %% [markdown]
# If a model is created with the pincell, it can be run with openMC with
#
# ```python
#     mod = pincell(1.26,0.0)
#     output = mod.run()
# ```
#
# where the `output` variable will contain the path to the state point file.
#
# Now we will call this function in a loop for several pitch values and then as a nested loop for three void values at each moderator to fuel ratio. Since the code will create the statepoint files with the same name, make sure that you store the quantity of interest (for example in arrays) before overwriting the output. At each moderator to fuel ratio you can perform a fit to estimate the void-coefficient (it can be a linear fit, considering that we will have only three values to fit for).
#
# Note that in case the computation seems to be slow, you should not use more than 500 particles per batch (you should get reasonably good results with 500 particles as well).
#
# Reminder: the statepoint files can be read with `sp = openmc.StatePoint(pathtofile)`, and the multiplication factor accessed with `sp.keff.nominal_value`.

# %%
from scipy.optimize import curve_fit

os.system('rm *h5')

pitch = np.arange(0.95, 3.05, 0.1)
void = [0,25,50]

all_results = []
#initialize lists to store results
for pi in pitch:
    #initialize list to store keff values
    for v in void:
        mod = pincell(pitch=pi,void=v)
        output = mod.run()
        
        sp = openmc.StatePoint(output)
        all_results.append(sp.keff.nominal_value)
        
        os.system('rm %s'%output)
        os.system('rm summary.h5')
    #your code to estimate the void-coefficient from a linear fit. and to store the data
# Out:
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:10:24
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13108
#         2/1    1.14546
#         3/1    0.99288
#         4/1    1.19123
#         5/1    0.98078
#         6/1    1.13447
#         7/1    1.13869
#         8/1    0.97302
#         9/1    1.09411
#        10/1    1.12823
#        11/1    1.04415
#        12/1    1.13843    1.09129 +/- 0.04714
#        13/1    1.16548    1.11602 +/- 0.03677
#        14/1    1.12957    1.11941 +/- 0.02622
#        15/1    1.12191    1.11991 +/- 0.02032
#        16/1    1.05496    1.10908 +/- 0.01981
#        17/1    1.14963    1.11487 +/- 0.01772
#        18/1    1.14190    1.11825 +/- 0.01571
#        19/1    0.98255    1.10317 +/- 0.02048
#        20/1    0.98592    1.09145 +/- 0.02175
#        21/1    0.94273    1.07793 +/- 0.02387
#        22/1    1.04689    1.07534 +/- 0.02194
#        23/1    1.11943    1.07873 +/- 0.02047
#        24/1    0.94353    1.06908 +/- 0.02127
#        25/1    1.13599    1.07354 +/- 0.02030
#        26/1    1.01193    1.06969 +/- 0.01937
#        27/1    1.08263    1.07045 +/- 0.01821
#        28/1    1.27620    1.08188 +/- 0.02063
#        29/1    1.25024    1.09074 +/- 0.02143
#        30/1    1.02331    1.08737 +/- 0.02061
#        31/1    1.11074    1.08848 +/- 0.01963
#        32/1    1.06320    1.08733 +/- 0.01875
#        33/1    1.06678    1.08644 +/- 0.01794
#        34/1    1.02603    1.08392 +/- 0.01736
#        35/1    0.93796    1.07808 +/- 0.01765
#        36/1    1.03461    1.07641 +/- 0.01704
#        37/1    1.06134    1.07585 +/- 0.01640
#        38/1    1.10755    1.07699 +/- 0.01585
#        39/1    1.13332    1.07893 +/- 0.01541
#        40/1    0.97004    1.07530 +/- 0.01533
#        41/1    1.10143    1.07614 +/- 0.01485
#        42/1    1.20401    1.08014 +/- 0.01492
#        43/1    1.09597    1.08062 +/- 0.01447
#        44/1    1.09230    1.08096 +/- 0.01404
#        45/1    1.10896    1.08176 +/- 0.01366
#        46/1    1.18923    1.08475 +/- 0.01361
#        47/1    1.01949    1.08298 +/- 0.01335
#        48/1    1.04173    1.08190 +/- 0.01304
#        49/1    1.01809    1.08026 +/- 0.01281
#        50/1    1.03875    1.07922 +/- 0.01252
#        51/1    1.25908    1.08361 +/- 0.01298
#        52/1    1.14657    1.08511 +/- 0.01275
#        53/1    0.97789    1.08262 +/- 0.01270
#        54/1    1.03122    1.08145 +/- 0.01246
#        55/1    1.11982    1.08230 +/- 0.01221
#        56/1    1.12437    1.08321 +/- 0.01198
#        57/1    1.09693    1.08351 +/- 0.01173
#        58/1    1.18109    1.08554 +/- 0.01166
#        59/1    1.15025    1.08686 +/- 0.01149
#        69/1    0.99860    1.02134 +/- 0.00999
#        70/1    0.98340    1.02071 +/- 0.00984
#        71/1    0.89052    1.01858 +/- 0.00991
#        72/1    1.07369    1.01946 +/- 0.00979
#        73/1    1.04629    1.01989 +/- 0.00964
#        74/1    0.89949    1.01801 +/- 0.00968
#        75/1    1.03096    1.01821 +/- 0.00953
#        76/1    1.01468    1.01815 +/- 0.00938
#        77/1    1.05929    1.01877 +/- 0.00926
#        78/1    0.88576    1.01681 +/- 0.00933
#        79/1    1.08270    1.01777 +/- 0.00925
#        80/1    1.05934    1.01836 +/- 0.00913
#        81/1    0.94491    1.01733 +/- 0.00906
#        82/1    0.93580    1.01619 +/- 0.00901
#        83/1    1.04138    1.01654 +/- 0.00889
#        84/1    1.01659    1.01654 +/- 0.00877
#        85/1    1.02439    1.01664 +/- 0.00865
#        86/1    0.97670    1.01612 +/- 0.00855
#        87/1    1.03663    1.01639 +/- 0.00845
#        88/1    1.14992    1.01810 +/- 0.00851
#        89/1    1.07029    1.01876 +/- 0.00843
#        90/1    0.96306    1.01806 +/- 0.00835
#        91/1    1.08985    1.01895 +/- 0.00829
#        92/1    0.95960    1.01822 +/- 0.00823
#        93/1    0.98030    1.01777 +/- 0.00814
#        94/1    1.14957    1.01934 +/- 0.00819
#        95/1    1.03352    1.01950 +/- 0.00810
#        96/1    1.03231    1.01965 +/- 0.00800
#        97/1    0.96978    1.01908 +/- 0.00793
#        98/1    1.10234    1.02003 +/- 0.00790
#        99/1    1.06219    1.02050 +/- 0.00782
#       100/1    1.05565    1.02089 +/- 0.00775
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.7546e+00 seconds
#    Reading cross sections          = 4.6436e+00 seconds
#  Total time in simulation          = 1.5152e+01 seconds
#    Time in transport only          = 1.4939e+01 seconds
#    Time in inactive batches        = 1.4667e+00 seconds
#    Time in active batches          = 1.3685e+01 seconds
#    Time synchronizing fission bank = 5.9954e-02 seconds
#      Sampling source sites         = 2.6833e-02 seconds
#      SEND/RECV source sites        = 2.8003e-02 seconds
#    Time accumulating tallies       = 4.4816e-04 seconds
#    Time writing statepoints        = 5.0198e-02 seconds
#  Total time for finalization       = 8.9375e-05 seconds
#  Total time elapsed                = 1.9989e+01 seconds
#  Calculation Rate (inactive)       = 3409.12 particles/second
#  Calculation Rate (active)         = 3288.28 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.01823 +/- 0.00644
#  k-effective (Track-length)  = 1.02089 +/- 0.00775
#  k-effective (Absorption)    = 1.02425 +/- 0.00469
#  Combined k-effective        = 1.02142 +/- 0.00438
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:11:03
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.92089
#         2/1    0.87184
#         3/1    0.90834
#         4/1    0.86747
#         5/1    0.95751
#         6/1    0.96685
#         7/1    1.00033
#         8/1    0.91308
#         9/1    0.95679
#        10/1    0.93693
#        11/1    0.89959
#        12/1    0.90914    0.90437 +/- 0.00478
#        13/1    0.95331    0.92068 +/- 0.01655
#        14/1    0.92562    0.92192 +/- 0.01177
#        15/1    0.94670    0.92687 +/- 0.01037
#        16/1    0.89156    0.92099 +/- 0.01031
#        17/1    0.85273    0.91124 +/- 0.01308
#        79/1    0.93655    0.93314 +/- 0.00693
#        80/1    0.84144    0.93183 +/- 0.00695
#        81/1    0.91799    0.93163 +/- 0.00686
#        82/1    0.85323    0.93054 +/- 0.00685
#        83/1    0.81814    0.92900 +/- 0.00693
#        84/1    0.97458    0.92962 +/- 0.00686
#        85/1    0.99268    0.93046 +/- 0.00682
#        86/1    0.90206    0.93009 +/- 0.00674
#        87/1    0.92395    0.93001 +/- 0.00665
#        88/1    0.95027    0.93027 +/- 0.00657
#        89/1    0.96148    0.93066 +/- 0.00650
#        90/1    0.88972    0.93015 +/- 0.00644
#        91/1    0.86838    0.92939 +/- 0.00641
#        92/1    0.80236    0.92784 +/- 0.00651
#        93/1    0.92088    0.92775 +/- 0.00644
#        94/1    0.95532    0.92808 +/- 0.00637
#        95/1    0.95250    0.92837 +/- 0.00630
#        96/1    0.94214    0.92853 +/- 0.00623
#        97/1    0.93752    0.92863 +/- 0.00616
#        98/1    0.99096    0.92934 +/- 0.00613
#        99/1    0.94787    0.92955 +/- 0.00606
#       100/1    0.96981    0.93000 +/- 0.00601
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.7700e+00 seconds
#    Reading cross sections          = 4.6601e+00 seconds
#  Total time in simulation          = 1.7272e+01 seconds
#    Time in transport only          = 1.7078e+01 seconds
#    Time in inactive batches        = 1.7626e+00 seconds
#    Time in active batches          = 1.5509e+01 seconds
#    Time synchronizing fission bank = 5.5077e-02 seconds
#      Sampling source sites         = 2.5172e-02 seconds
#      SEND/RECV source sites        = 2.4749e-02 seconds
#    Time accumulating tallies       = 4.5625e-04 seconds
#    Time writing statepoints        = 4.6679e-02 seconds
#  Total time for finalization       = 8.4709e-05 seconds
#  Total time elapsed                = 2.2123e+01 seconds
#  Calculation Rate (inactive)       = 2836.79 particles/second
#  Calculation Rate (active)         = 2901.54 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.92992 +/- 0.00545
#  k-effective (Track-length)  = 0.93000 +/- 0.00601
#  k-effective (Absorption)    = 0.93020 +/- 0.00462
#  Combined k-effective        = 0.93010 +/- 0.00420
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:11:25
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.17870
#         2/1    1.18863
#         3/1    1.32284
#         4/1    1.20739
#         5/1    1.32752
#         6/1    1.28688
#         7/1    1.32983
#         8/1    1.22809
#         9/1    1.35010
#        10/1    1.22845
#        11/1    1.28348
#        12/1    1.20772    1.24560 +/- 0.03788
#        13/1    1.18026    1.22382 +/- 0.03086
#        14/1    1.21176    1.22080 +/- 0.02203
#        15/1    1.14385    1.20541 +/- 0.02298
#        16/1    1.15892    1.19766 +/- 0.02030
#        17/1    1.35124    1.21960 +/- 0.02785
#        18/1    1.28748    1.22809 +/- 0.02557
#        19/1    1.18633    1.22345 +/- 0.02302
#        20/1    1.21874    1.22298 +/- 0.02060
#        21/1    1.20017    1.22090 +/- 0.01875
#        22/1    1.20332    1.21944 +/- 0.01717
#        23/1    1.40446    1.23367 +/- 0.02126
#        24/1    1.15450    1.22802 +/- 0.02048
#        25/1    1.36107    1.23689 +/- 0.02103
#        26/1    1.17613    1.23309 +/- 0.02004
#        27/1    1.21371    1.23195 +/- 0.01885
#        89/1    1.27264    1.22339 +/- 0.00811
#        90/1    1.20893    1.22321 +/- 0.00801
#        91/1    1.23470    1.22335 +/- 0.00791
#        92/1    1.16618    1.22265 +/- 0.00784
#        93/1    1.21569    1.22257 +/- 0.00775
#        94/1    1.26146    1.22303 +/- 0.00767
#        95/1    1.34554    1.22447 +/- 0.00771
#        96/1    1.23402    1.22458 +/- 0.00762
#        97/1    1.29665    1.22541 +/- 0.00758
#        98/1    1.13133    1.22434 +/- 0.00757
#        99/1    1.30501    1.22525 +/- 0.00754
#       100/1    1.44009    1.22764 +/- 0.00783
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.7727e+00 seconds
#    Reading cross sections          = 4.6588e+00 seconds
#  Total time in simulation          = 1.0145e+01 seconds
#    Time in transport only          = 9.9674e+00 seconds
#    Time in inactive batches        = 1.0143e+00 seconds
#    Time in active batches          = 9.1312e+00 seconds
#    Time synchronizing fission bank = 5.5122e-02 seconds
#      Sampling source sites         = 2.5515e-02 seconds
#      SEND/RECV source sites        = 2.4838e-02 seconds
#    Time accumulating tallies       = 3.1808e-04 seconds
#    Time writing statepoints        = 4.3058e-02 seconds
#  Total time for finalization       = 8.1083e-05 seconds
#  Total time elapsed                = 1.5000e+01 seconds
#  Calculation Rate (inactive)       = 4929.4 particles/second
#  Calculation Rate (active)         = 4928.17 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.22991 +/- 0.00589
#  k-effective (Track-length)  = 1.22764 +/- 0.00783
#  k-effective (Absorption)    = 1.22879 +/- 0.00462
#  Combined k-effective        = 1.22915 +/- 0.00433
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:11:40
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13805
#         2/1    1.09631
#         3/1    1.15054
#         4/1    1.12562
#         5/1    1.15454
#         6/1    1.19619
#         7/1    1.15376
#         8/1    1.27161
#         9/1    1.14894
#        10/1    1.08222
#        11/1    1.14200
#        12/1    1.06814    1.10507 +/- 0.03693
#        13/1    1.18232    1.13082 +/- 0.03343
#        14/1    1.10834    1.12520 +/- 0.02430
#        15/1    1.19556    1.13927 +/- 0.02350
#        16/1    1.12274    1.13652 +/- 0.01939
#        17/1    1.05380    1.12470 +/- 0.02020
#        18/1    1.20872    1.13520 +/- 0.02040
#        19/1    1.06566    1.12748 +/- 0.01958
#        20/1    1.15939    1.13067 +/- 0.01780
#        21/1    1.14252    1.13174 +/- 0.01614
#        22/1    1.06986    1.12659 +/- 0.01561
#        23/1    1.11115    1.12540 +/- 0.01441
#        24/1    1.21413    1.13174 +/- 0.01477
#        25/1    1.17468    1.13460 +/- 0.01404
#        26/1    1.24316    1.14139 +/- 0.01479
#        27/1    1.24456    1.14745 +/- 0.01516
#        28/1    1.16778    1.14858 +/- 0.01433
#        29/1    1.21455    1.15206 +/- 0.01400
#        30/1    1.37727    1.16332 +/- 0.01741
#        31/1    1.17380    1.16382 +/- 0.01657
#        32/1    1.17923    1.16452 +/- 0.01581
#        33/1    1.06656    1.16026 +/- 0.01570
#        34/1    1.24800    1.16391 +/- 0.01547
#        35/1    1.12514    1.16236 +/- 0.01492
#        36/1    1.17659    1.16291 +/- 0.01434
#        37/1    1.13383    1.16183 +/- 0.01384
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.9171e+00 seconds
#    Reading cross sections          = 4.7988e+00 seconds
#  Total time in simulation          = 1.2953e+01 seconds
#    Time in transport only          = 1.2731e+01 seconds
#    Time in inactive batches        = 1.3120e+00 seconds
#    Time in active batches          = 1.1641e+01 seconds
#    Time synchronizing fission bank = 6.5838e-02 seconds
#      Sampling source sites         = 3.1077e-02 seconds
#      SEND/RECV source sites        = 2.9247e-02 seconds
#    Time accumulating tallies       = 3.8987e-04 seconds
#    Time writing statepoints        = 4.9095e-02 seconds
#  Total time for finalization       = 9.2792e-05 seconds
#  Total time elapsed                = 1.7952e+01 seconds
#  Calculation Rate (inactive)       = 3810.87 particles/second
#  Calculation Rate (active)         = 3865.73 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.15916 +/- 0.00639
#  k-effective (Track-length)  = 1.16438 +/- 0.00754
#  k-effective (Absorption)    = 1.15559 +/- 0.00522
#  Combined k-effective        = 1.15672 +/- 0.00503
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:11:59
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18976
#         2/1    1.15643
#         3/1    1.10412
#         4/1    1.08534
#         5/1    1.02787
#         6/1    0.98131
#         7/1    1.09069
#         8/1    1.05603
#         9/1    1.01165
#        10/1    1.03071
#        11/1    1.07990
#        12/1    0.95868    1.01929 +/- 0.06061
#        13/1    1.01325    1.01727 +/- 0.03505
#        14/1    0.87193    0.98094 +/- 0.04398
#        15/1    1.05490    0.99573 +/- 0.03714
#        16/1    1.09035    1.01150 +/- 0.03418
#        17/1    1.06046    1.01850 +/- 0.02972
#        18/1    1.02196    1.01893 +/- 0.02574
#        19/1    0.93455    1.00955 +/- 0.02456
#        20/1    1.12590    1.02119 +/- 0.02486
#        21/1    1.04480    1.02333 +/- 0.02259
#        22/1    1.21881    1.03962 +/- 0.02628
#        23/1    1.05142    1.04053 +/- 0.02419
#        24/1    1.02488    1.03941 +/- 0.02242
#        25/1    1.09712    1.04326 +/- 0.02123
#        26/1    1.00627    1.04095 +/- 0.01999
#        27/1    1.02076    1.03976 +/- 0.01882
#        28/1    1.04226    1.03990 +/- 0.01774
#        29/1    1.00813    1.03823 +/- 0.01686
#        30/1    1.16752    1.04469 +/- 0.01725
#        31/1    1.03330    1.04415 +/- 0.01642
#        32/1    1.08448    1.04598 +/- 0.01576
#        33/1    1.19550    1.05248 +/- 0.01641
#        34/1    0.98829    1.04981 +/- 0.01593
#        35/1    1.07931    1.05099 +/- 0.01533
#        36/1    1.12149    1.05370 +/- 0.01497
#        37/1    1.11859    1.05610 +/- 0.01461
#        38/1    0.92447    1.05140 +/- 0.01484
#        39/1    1.02444    1.05047 +/- 0.01435
#        40/1    0.99401    1.04859 +/- 0.01399
#        41/1    1.01620    1.04755 +/- 0.01357
#        42/1    1.11064    1.04952 +/- 0.01329
#        43/1    1.01797    1.04856 +/- 0.01292
#        44/1    1.10892    1.05034 +/- 0.01265
#        45/1    1.11133    1.05208 +/- 0.01241
#        46/1    1.07875    1.05282 +/- 0.01208
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.29479 +/- 0.00578
#  k-effective (Track-length)  = 1.29808 +/- 0.00759
#  k-effective (Absorption)    = 1.29008 +/- 0.00450
#  Combined k-effective        = 1.29223 +/- 0.00384
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/source.py:390: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | fa2330103de61a864c958d1a7250f11e5dd91468
#        Date/Time | 2024-04-18 10:25:08
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.39101
#         2/1    1.50645
#         3/1    1.45244
#         4/1    1.42911
#         5/1    1.29319
#         6/1    1.38013
#         7/1    1.42752
#         8/1    1.36662
#         9/1    1.35994
#        10/1    1.32112
#        11/1    1.39069
#        12/1    1.41465    1.40267 +/- 0.01198
#        13/1    1.35516    1.38683 +/- 0.01728
#        14/1    1.43265    1.39829 +/- 0.01675
#        15/1    1.36311    1.39125 +/- 0.01476
#        16/1    1.35824    1.38575 +/- 0.01325
#        17/1    1.44822    1.39468 +/- 0.01432
#        18/1    1.46032    1.40288 +/- 0.01487
#        19/1    1.33486    1.39532 +/- 0.01514
#        20/1    1.46213    1.40200 +/- 0.01510
#        21/1    1.52820    1.41348 +/- 0.01783
#        22/1    1.46588    1.41784 +/- 0.01686
#        23/1    1.39315    1.41594 +/- 0.01562
#        24/1    1.34605    1.41095 +/- 0.01530
#        25/1    1.41819    1.41143 +/- 0.01425
#        26/1    1.50253    1.41713 +/- 0.01450
#        27/1    1.39129    1.41561 +/- 0.01370
#        28/1    1.52226    1.42153 +/- 0.01421
#        29/1    1.53588    1.42755 +/- 0.01473
#        30/1    1.33581    1.42296 +/- 0.01471
#        31/1    1.32769    1.41843 +/- 0.01471
#        32/1    1.39432    1.41733 +/- 0.01406
#        33/1    1.30378    1.41239 +/- 0.01432
#        34/1    1.56298    1.41867 +/- 0.01508
#        35/1    1.26866    1.41267 +/- 0.01566
#        36/1    1.35107    1.41030 +/- 0.01523
#        37/1    1.49197    1.41332 +/- 0.01496
#        38/1    1.42979    1.41391 +/- 0.01443
#        39/1    1.44179    1.41487 +/- 0.01396
#        40/1    1.34180    1.41244 +/- 0.01370
#        41/1    1.46030    1.41398 +/- 0.01334
#        42/1    1.31004    1.41073 +/- 0.01332
#        43/1    1.50060    1.41346 +/- 0.01319
#        44/1    1.55541    1.41763 +/- 0.01346
#        45/1    1.41539    1.41757 +/- 0.01307
#        46/1    1.28930    1.41400 +/- 0.01319
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.40723 +/- 0.00578
#  k-effective (Track-length)  = 1.40990 +/- 0.00742
#  k-effective (Absorption)    = 1.40024 +/- 0.00405
#  Combined k-effective        = 1.40264 +/- 0.00357
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# Alright, now we have the k-eigenvalue for several pitch and void values, and we have the void coefficient at several pitch values. It is time to visualize them somehow. Try to create a figure which shows the void coefficient vs the moderator to fuel ratio and an other figure which shows the k-eigenvalue vs the moderator to fuel ratio for each void levels.
#
# Conclude your findings: how would you design a reactor core? which moderator to fuel ratio would you select?

# %%
all_results
slopes = []
for i in range(int(len(all_results) / 3)):
    slope, intercept = np.polyfit(void, all_results[i*3: i*3+3], 1)
    slopes.append(slope)

# %% [markdown]
# $$mfr=\frac{p^2-r_{clad}^2\pi}{r_{fuel}^2\pi}$$

# %%
r_clad = 0.3 # m
r_fuel = 0.41 # m 
mfr = (pitch**2 - r_clad **2 * np.pi) / (r_fuel **2 * np.pi)

# %%
for i in range(len(pitch)):
    plt.plot(void, all_results[i*3:i*3 + 3], label=str(round(mfr[i],2)) + "  " + str(round(slopes[i], 4)))

plt.legend()

# %%
plt.figure()
plt.plot(mfr, slopes)
#your code comes here to visualize the void coefficient vs moderator to fuel ratio
plt.xlabel("mfr")
plt.ylabel("void coefficient (a in f(x) = ax + b) ")
plt.show()

# %%
plt.figure()
for start, label in zip(range(3), [0, 25, 50]):
    plt.plot(mfr, [all_results[i] for i in np.arange(start, len(all_results),3)], label=f"{label}% void")
#your code comes here to visualize the k-eigenvalue vs moderator to fuel ratio
plt.xlabel("mfr")
plt.ylabel("k")
plt.legend()
plt.show()

# %% [markdown]
# Change this line to your conclusion!

# %% [markdown]
# ## Experiment 3
#
# Wow, we saw some interesting curve there, the k-infinity first increased with increasing the pitch and then it started to to decrease. Intuitively one expects that there are two competing physical phenonema at play here. And our intuition is correct. If you remember the 4-factor formula, there were two quantities which are of interest for us now to figure out why does the k-infinity change like this with the increasing pitch. And these two quantities are:
#
# **Resonance escape probability**: probability for fast neutrons to slow-down to thermal energies without being absorbed in the resonance region of absorbers
#
# $$p=1-\frac{\int_{V_{f}} \int_{\sim 5kT}^\infty \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{f}} \int_0^{\infty} \nu(E)\Sigma_f(r,E)\phi(r,E)dVdE}$$
#
#
# **Thermal utilization factor**: the ratio of the number of thermal neutrons absorbed in the fuel and the number of thermal neutrons absorbed in all materials
#
# $$f=\frac{\int_{V_{f}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{t}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}$$
#
# The nominators and the denominators look like the expressions we used to define the tallies. The "scores" here are absorption, and nu-fission and the filters are the energy bounds and the spatial regions. So let's add these tallies to our `pincell()` function (for the tallies we will need to fix the ID, since we will refer to them later):

# %%
def pincell(pitch):
    #your input comes here, you can remove the void from your previous function
    #tallies
    T=1200
    k=8.617333262145e-5
    energy_filter = openmc.EnergyFilter([0., 5*k*T, 20.0e6])
    fuel_filter = openmc.CellFilter(fuel)
    moderator_filter = openmc.CellFilter(moderator)
    tally1 = openmc.Tally(1)
    tally1.filters = [fuel_filter,energy_filter]
    tally1.scores = ['absorption','nu-fission']
    
    tally2 = openmc.Tally(2)
    tally2.filters = [moderator_filter,energy_filter]
    tally2.scores = ['absorption']
    tallies = openmc.Tallies([tally1, tally2])
    model = openmc.model.Model(geom, mats, settings,tallies)
    return model

# %% [markdown]
# Now we just have to figure out how to compute $p$ and $f$ from the tallies. First it is best to remind ourselves how to load in the tally results, and you can do some trial and error to figure out these values. Let's run a computation with our model.

# %%
os.system('rm *h5')
mod=pincell(1.26)
output = mod.run()
# Out:
# rm: cannot remove '*h5': No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 os.system('rm *h5')
# ----> 2 mod=pincell(1.26)
#       3 output = mod.run()
#
# Cell In[7], line 7, in pincell(pitch)
#       5 k=8.617333262145e-5
#       6 energy_filter = openmc.EnergyFilter([0., 5*k*T, 20.0e6])
# ----> 7 fuel_filter = openmc.CellFilter(fuel)
#       8 moderator_filter = openmc.CellFilter(moderator)
#       9 tally1 = openmc.Tally(1)
#
# NameError: name 'fuel' is not defined

# %% [markdown]
# And now load in the tallies. And from there you can perform the necessary operations to obtain $p$ and $f$.

# %%
sp = openmc.StatePoint(output)
tallydf1 = sp.tallies[1].get_pandas_dataframe()
tallydf1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sp = openmc.StatePoint(output)
#       2 tallydf1 = sp.tallies[1].get_pandas_dataframe()
#       3 tallydf1
#
# NameError: name 'output' is not defined

# %%
sp = openmc.StatePoint(output)
tallydf2 = sp.tallies[2].get_pandas_dataframe()
tallydf2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sp = openmc.StatePoint(output)
#       2 tallydf2 = sp.tallies[2].get_pandas_dataframe()
#       3 tallydf2
#
# NameError: name 'output' is not defined

# %%
#test here how p and f should be estimated

# %% [markdown]
# Once we know how to get these quantities we can loop through several pitch values to see how they change with the moderator to fuel ratio!

# %%
pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]
os.system('rm *h5')
keff=[]
p=[]
f=[]
for pi in pitch:
    #create a model
    #run the model
    #read the statepoint file and the tallies
    keff.append#complete the line
    p.append#complete the line
    f.append#complete the line
    os.system('rm *h5')

# %% [markdown]
# Finally we are ready to visualize our results and then conclude our findings. Try to summarize with few words the underlying physics what we just discovered here.

# %%
mfr=#complete the line

plt.figure()
plt.plot(mfr,keff,label='k-inf')
plt.plot(mfr,p,label='p')
plt.plot(mfr,f,label='f')
plt.legend()
plt.xlabel('Moderator to fuel ratio')
plt.show()

# %% [markdown]
# Change this line to your conclusions!
